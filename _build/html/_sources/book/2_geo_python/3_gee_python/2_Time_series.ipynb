# %% [markdown]
# # 3.2 - Time Series

# %% [markdown]
# ## ImageCollection

# %% [markdown]
# An ImageCollection is a stack or time series of images. In addition to loading an ImageCollection using an Earth Engine collection ID, Earth Engine has methods to create image collections. The constructor `ee.ImageCollection()` or the convenience method `ee.ImageCollection.fromImages()` create image collections from lists of images. While single images are great to do quick analytics, the true power of the Earth Engine environment comes with the possibility of looking at really large and heavy image collections and to be able to push analysis towards the data, rather than the need for the data to travel at all. In the GEE environment image collections have their own characteristic setup and are composted with single images that we discussed earlier. They can often have the same or different band structure but generally share a similar metadata structure for filtering and querying.
#
# Large scale image collections such as Landsat and Sentinel image collections are ingested on the fly and are actively maintained till there imagery and processing pipelines feeds are maintained byt he agencies supplying the imagery. Images as well as image collections can be moved into GEE environment to allow you to use both your data and the GEE catalog data within the same platform.
#
# These image collection as well as individual images again have defined data type,scales and projections along with some default properties such as an index and ID among other system properties. To have a look at all of the raster catalog you can find them listed [here](https://developers.google.com/earth-engine/datasets/catalog/).
#
# You can also create new image collections by merging existing collections.

# %%
# Import earthengine API
import ee
# Authenticate and initialise 
ee.Authenticate()
ee.Initialize()

# %%
# Create arbitary constant images
constant1 = ee.Image(1)
constant2 = ee.Image(2)

# Create a collection by giving a list to the constructor.
collectionFromConstructor = ee.ImageCollection([constant1, constant2])
print('collectionFromConstructor: ', collectionFromConstructor.getInfo())

# Create a collection with fromImages().
collectionFromImages = ee.ImageCollection.fromImages([ee.Image(3), ee.Image(4)])
print('collectionFromImages: ', collectionFromImages.getInfo());

# Merge two collections.
mergedCollection = collectionFromConstructor.merge(collectionFromImages);
print('mergedCollection: ', mergedCollection.getInfo());
# Out:
# collectionFromConstructor:  {'type': 'ImageCollection', 'bands': [], 'features': [{'type': 'Image', 'bands': [{'id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 1, 'max': 1}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '0'}}, {'type': 'Image', 'bands': [{'id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 2, 'max': 2}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '1'}}]}
# collectionFromImages:  {'type': 'ImageCollection', 'bands': [], 'features': [{'type': 'Image', 'bands': [{'id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 3, 'max': 3}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '0'}}, {'type': 'Image', 'bands': [{'id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 4, 'max': 4}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '1'}}]}
# mergedCollection:  {'type': 'ImageCollection', 'bands': [], 'features': [{'type': 'Image', 'bands': [{'id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 1, 'max': 1}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '1_0'}}, {'type': 'Image', 'bands': [{'id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 2, 'max': 2}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '1_1'}}, {'type': 'Image', 'bands': [{'id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 3, 'max': 3}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '2_0'}}, {'type': 'Image', 'bands': [{'id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 4, 'max': 4}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '2_1'}}]}

# %% [markdown]
# ## Image Collection metadata and information

# %% [markdown]
# As with Images, there are a variety of ways to get information about an ImageCollection. The collection can be printed directly to the console, but the console printout is limited to 5000 elements. Collections larger than 5000 images will need to be filtered before printing. Printing a large collection will be correspondingly slower. The following example shows various ways of getting information about image collections programmatically:

# %%
import pprint

# Configure the pretty printing output & initialize earthengine.
pp = pprint.PrettyPrinter(depth=4)

# Load a Landsat 8 ImageCollection for a single path-row.
collection = (ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA')
    .filter(ee.Filter.eq('WRS_PATH', 44))
    .filter(ee.Filter.eq('WRS_ROW', 34))
    .filterDate('2014-03-01', '2014-08-01'))
#pp.pprint('Collection: '+str(collection.getInfo())+'\n')

# Get the number of images.
count = collection.size()
print('Number of images in collection: ', str(count.getInfo())+'\n')

# Get the date range of images in the collection.
range = collection.reduceColumns(ee.Reducer.minMax(), ["system:time_start"])
print('Date range: ', str(ee.Date(range.get('min')).getInfo()), str(ee.Date(range.get('max')).getInfo())+'\n')

# Get statistics for a property of the images in the collection.
sunStats = collection.aggregate_stats('SUN_ELEVATION')
pp.pprint('Sun elevation statistics: '+str(sunStats.getInfo())+'\n')

# Sort by a cloud cover property, get the least cloudy image.
image = ee.Image(collection.sort('CLOUD_COVER').first())
print('Least cloudy image: ', str(image.getInfo())+'\n')

# Limit the collection to the 5 most recent images.
recent = collection.sort('system:time_start', False).limit(5)
#pp.pprint('Recent images: '+str(recent.getInfo())+'\n')

# Get size of collection in bytes
print('Total size of Collection with 5 most recent images : '+str((recent.reduceColumns(ee.Reducer.sum(), ['system:asset_size']).getInfo()['sum'])))
# Out:
# Number of images in collection:  9
#
# Date range:  {'type': 'Date', 'value': 1395168392053} {'type': 'Date', 'value': 1406227557219}
#
# ("Sun elevation statistics: {'max': 67.10252727, 'mean': 61.01998433666667, "
#  "'min': 46.47106522, 'sample_sd': 7.251804446695445, 'sample_var': "
#  "52.58866773311183, 'sum': 549.17985903, 'sum_sq': 33931.6557378883, "
#  "'total_count': 9, 'total_sd': 6.837066800129478, 'total_var': "
#  "46.74548242943274, 'valid_count': 9, 'weight_sum': 9, 'weighted_sum': "
#  '549.17985903}\n')
# Least cloudy image:  {'type': 'Image', 'bands': [{'id': 'B1', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B6', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B7', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B8', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [15321, 15601], 'crs': 'EPSG:32610', 'crs_transform': [15, 0, 460792.5, 0, -15, 4264207.5]}, {'id': 'B9', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B10', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'B11', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'QA_PIXEL', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'QA_RADSAT', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'SAA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'SZA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'VAA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}, {'id': 'VZA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7661, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 460785, 0, -30, 4264215]}], 'version': 1742759744720687, 'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20140318', 'properties': {'RADIANCE_MULT_BAND_5': 0.0061709, 'RADIANCE_MULT_BAND_6': 0.0015346, 'RADIANCE_MULT_BAND_3': 0.011958, 'RADIANCE_MULT_BAND_4': 0.010084, 'RADIANCE_MULT_BAND_1': 0.012673, 'RADIANCE_MULT_BAND_2': 0.012977, 'WRS_TYPE': 2, 'K2_CONSTANT_BAND_11': 1201.1442, 'K2_CONSTANT_BAND_10': 1321.0789, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-120.82829120245813, 38.12674271231532], [-120.82825562226986, 38.12794465488719], [-122.94816146043102, 38.52557438907335], [-122.95017392636679, 38.525575241513984], [-122.95103687833704, 38.52422133103557], [-122.9569591344694, 38.504384836247866], [-123.43819639576931, 36.8067677093856], [-123.43818715731503, 36.80515197239888], [-122.59741883356627, 36.649103679754695], [-121.7447578273677, 36. ...
#
# Total size of Collection with 5 most recent images : 6369281283

# %% [markdown]
# ## Filtering an ImageCollection

# %% [markdown]
# Specifically, many common use cases are handled by `imageCollection.filterDate()`, and `imageCollection.filterBounds()`. For general purpose filtering, use `imageCollection.filter()` with an `ee.Filter` as an argument. The following example demonstrates both convenience methods and `filter()` to identify and remove images with bad registration from an ImageCollection:

# %%
# Load Landsat 5 data, filter by date and bounds.
collection = ee.ImageCollection('LANDSAT/LT05/C02/T2').filterDate('1987-01-01', '1990-05-01').filterBounds(ee.Geometry.Point(25.8544, -18.08874))

# Also filter the collection by the IMAGE_QUALITY property.
filtered = collection.filterMetadata('IMAGE_QUALITY', 'equals', 9)

# Create two composites to check the effect of filtering by IMAGE_QUALITY.
badComposite = ee.Algorithms.Landsat.simpleComposite(collection, 75, 3) # percentile and cloud score
goodComposite = ee.Algorithms.Landsat.simpleComposite(filtered, 75, 3)

# %%
# Display the composites.

import folium
# !pip install geehydro # Life saver for plotting GEE stuff with Python!
import geehydro

# Use folium to visualize the imagery.
map = folium.Map(location=[-18.08874,25.8544],zoom_start=9)

map.addLayer(goodComposite, {'bands': ['B3', 'B2', 'B1'], 'gain':3.5}, 'good composite')
map.addLayer(badComposite, {'bands': ['B3', 'B2', 'B1'], 'gain':3.5}, 'bad composite')
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6015e6e07a0878aba7f7775cd824993 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6015e6e07a0878aba7f7775cd824993&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6015e6e07a0878aba7f7775cd824993 = L.map(
#                 &quot;map_c6015e6e07a0878aba7f7775cd824993&quot;,
#                 {
#                     center: [-18.08874, 25.8544],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc5a0e5fe1fe0fca71bce0130e83d229 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc5a0e5fe1fe0fca71bce0130e83d229.addTo(map_c6015e6e07a0878aba7f7775cd824993);
#
#
#             var tile_layer_922dd5026698c0632930a1eafeac8e43 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/522364178051/maps/8a193715a67182aa1cd2d579e7522518-5d104b568b96c8dd3e12d5620c01b7b7/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_922dd5026698c0632930a1eafeac8e43.addTo(map_c6015e6e07a0878aba7f7775cd824993);
#
#
#             var tile_layer_27c0e0c77b0cad3c053d493025ef56ad = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/522364178051/maps/19c8d8c3ffebf92f98345c77de934aed-23167dd5bfbaa800fc18dc61f8dc89ea/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27c0e0c77b0cad3c053d493025ef56ad.addTo(map_c6015e6e07a0878aba7f7775cd824993);
#
#
#             var layer_control_7bffeb6df17b6513ebac0b7ef1b54e76_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_fc5a0e5fe1fe0fca71bce0130e83d229,
#                 },
#                 overlays :  {
#                     &quot;good composite&quot; : tile_layer_922dd5026698c0632930a1eafeac8e43,
#                     &quot;bad composite&quot; : tile_layer_27c0e0c77b0cad3c053d493025ef56ad,
#                 },
#             };
#             let layer_control_7bffeb6df17b6513ebac0b7ef1b54e76 = L.control.layers(
#                 layer_control_7bffeb6df17b6513ebac0b7ef1b54e76_layers.base_layers,
#                 layer_control_7bffeb6df17b6513ebac0b7ef1b54e76_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c6015e6e07a0878aba7f7775cd824993);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Mapping over an ImageCollection

# %% [markdown]
# To apply a function to every Image in an ImageCollection use `imageCollection.map()`. The only argument to `map()` is a function which takes one parameter: an `ee.Image`. For example, the following code adds a timestamp band to every image in the collection:

# %%
# Load a Landsat 8 collection for a single path-row.
collection = ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA').filter(ee.Filter.eq('WRS_PATH', 44)).filter(ee.Filter.eq('WRS_ROW', 34))

# This function adds a band representing the image timestamp.
def addTime(image):
    return image.addBands(image.metadata('system:time_start'))

# Map the function over the collection and display the result.
# print(collection.map(addTime))

# %% [markdown]
# The `map()` function is equivalent to a `for` loop in Earth Engine.
#
# The mapped function is limited in the operations it can perform. Specifically, it can’t modify variables outside the function; it can’t print anything; it can’t use ‘if’ or ‘for’ statements. However, you can use `ee.Algorithms.If()` to perform conditional operations in a mapped function. For example:

# %%
# This function uses a conditional statement to return the image if
# the solar elevation > 40 degrees.  Otherwise it returns a zero image.
def conditional(image):
  return ee.Algorithms.If(ee.Number(image.get('SUN_ELEVATION')).gt(60),image,ee.Image(0))

result = collection.map(conditional)

# Print it
#!pip install pprint
import pprint
# Configure the pretty printing output
pp = pprint.PrettyPrinter(depth=4)
pp.pprint(result.getInfo())
# Out:
# {'bands': [],
#  'features': [{'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20130404'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20130409'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20130416'},
#                'type': 'Image'},
#               {'bands': [{...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...}],
#                'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20130603',
#                'properties': {'CLOUD_COVER': 37.72,
#                               'CLOUD_COVER_LAND': 9.35,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 2,
#                               'DATA_SOURCE_ELEVATION': 'GLS2000',
#                               'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#                               'DATE_ACQUIRED': '2013-06-03',
#                               'DATE_PRODUCT_GENERATED': 1599945115000,
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0144307,
#                               'ELLIPSOID': 'WGS84',
#                               'GEOMETRIC_RMSE_MODEL': 3.825,
#                               'GEOMETRIC_RMSE_MODEL_X': 2.519,
#                               'GEOMETRIC_RMSE_MODEL_Y': 2.878,
#                               'GEOMETRIC_RMSE_VERIFY': 1.598,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 907,
#                               'GROUND_CONTROL_POINTS_VERIFY': 304,
#                               'GROUND_CONTROL_POINTS_VERSION': 5,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853,
#                               'K1_CONSTANT_BAND_11': 480.8883,
#                               'K2_CONSTANT_BAND_10': 1321.0789,
#                               'K2_CONSTANT_BAND_11': 1201.1442,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20130603_20200912_02_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342013154LGN01',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 14741,
#                               'PANCHROMATIC_SAMPLES': 15141,
#                               'PROCESSING_LEVEL': 'L1TP',
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#                               'RADIANCE_ADD_BAND_1': -61.00537,
#                               'RADIANCE_ADD_BAND_10': 0.1,
#                               'RADIANCE_ADD_BAND_11': 0.1,
#                               'RADIANCE_ADD_BAND_2': -62.47024,
#                               'RADIANCE_ADD_BAND_3': -57.56579,
#                               'RADIANCE_ADD_BAND_4': -48.54272,
#                               'RADIANCE_ADD_BAND_5': -29.70572,
#                               'RADIANCE_ADD_BAND_6': -7.38754,
#                               'RADIANCE_ADD_BAND_7': -2.49,
#                               'RADIANCE_ADD_BAND_8': -54.937,
#                               'RADIANCE_ADD_BAND_9': -11.60967,
#                               'RADIANCE_MULT_BAND_1': 0.012201,
#                               'RADIANCE_MULT_BAND_10': 0.0003342,
#                               'RADIANCE_MULT_BAND_11': 0.0003342,
#                               'RADIANCE_MULT_BAND_2': 0.012494,
#                               'RADIANCE_MULT_BAND_3': 0.011513,
#                               'RADIANCE_MULT_BAND_4': 0.0097085,
#                               'RADIANCE_MULT_BAND_5': 0.0059411,
#                               'RADIANCE_MULT_BAND_6': 0.0014775,
#                               'RADIANCE_MULT_BAND_7': 0.000498,
#                               'RADIANCE_MULT_BAND_8': 0.010987,
#                               'RADIANCE_MULT_BAND_9': 0.0023219,
#                               'REFLECTANCE_ADD_BAND_1': -0.1,
#                               'REFLECTANCE_ADD_BAND_2': -0.1,
#                               'REFLECTANCE_ADD_BAND_3': -0.1,
#                               'REFLECTANCE_ADD_BAND_4': -0.1,
#                               'REFLECTANCE_ADD_BAND_5': -0.1,
#                               'REFLECTANCE_ADD_BAND_6': -0.1,
#                               'REFLECTANCE_ADD_BAND_7': -0.1,
#                               'REFLECTANCE_ADD_BAND_8': -0.1,
#                               'REFLECTANCE_ADD_BAND_9': -0.1,
#                               'REFLECTANCE_MULT_BAND_1': 2e-05,
#                               'REFLECTANCE_MULT_BAND_2': 2e-05,
#                               'REFLECTANCE_MULT_BAND_3': 2e-05,
#                               'REFLECTANCE_MULT_BAND_4': 2e-05,
#                               'REFLECTANCE_MULT_BAND_5': 2e-05,
#                               'REFLECTANCE_MULT_BAND_6': 2e-05,
#                               'REFLECTANCE_MULT_BAND_7': 2e-05,
#                               'REFLECTANCE_MULT_BAND_8': 2e-05,
#                               'REFLECTANCE_MULT_BAND_9': 2e-05,
#                               'REFLECTIVE_LINES': 7371,
#                               'REFLECTIVE_SAMPLES': 7571,
#                               'REQUEST_ID': 'L2',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'ROLL_ANGLE': -0.001,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:48:07.5781770Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 126.16896009,
#                               'SUN_ELEVATION': 67.34151603,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7371,
#                               'THERMAL_SAMPLES': 7571,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'WRS_TYPE': 2,
#                               'system:asset_size': 1188300485,
#                               'system:footprint': {...},
#                               'system:index': 'LC08_044034_20130603',
#                               'system:time_end': 1370285287578,
#                               'system:time_start': 1370285287578},
#                'type': 'Image',
#                'version': 1742759744720687},
#               {'bands': [{...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...}],
#                'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20130619',
#                'properties': {'CLOUD_COVER': 0.41,
#                               'CLOUD_COVER_LAND': 0.56,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 2,
#                               'DATA_SOURCE_ELEVATION': 'GLS2000',
#                               'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#                               'DATE_ACQUIRED': '2013-06-19',
#                               'DATE_PRODUCT_GENERATED': 1599928625000,
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0161153,
#                               'ELLIPSOID': 'WGS84',
#                               'GEOMETRIC_RMSE_MODEL': 3.181,
#                               'GEOMETRIC_RMSE_MODEL_X': 2.07,
#                               'GEOMETRIC_RMSE_MODEL_Y': 2.415,
#                               'GEOMETRIC_RMSE_VERIFY': 1.677,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 1080,
#                               'GROUND_CONTROL_POINTS_VERIFY': 384,
#                               'GROUND_CONTROL_POINTS_VERSION': 5,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853,
#                               'K1_CONSTANT_BAND_11': 480.8883,
#                               'K2_CONSTANT_BAND_10': 1321.0789,
#                               'K2_CONSTANT_BAND_11': 1201.1442,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20130619_20200912_02_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342013170LGN01',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 14741,
#                               'PANCHROMATIC_SAMPLES': 15141,
#                               'PROCESSING_LEVEL': 'L1TP',
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#                               'RADIANCE_ADD_BAND_1': -60.80325,
#                               'RADIANCE_ADD_BAND_10': 0.1,
#                               'RADIANCE_ADD_BAND_11': 0.1,
#                               'RADIANCE_ADD_BAND_2': -62.26327,
#                               'RADIANCE_ADD_BAND_3': -57.37508,
#                               'RADIANCE_ADD_BAND_4': -48.3819,
#                               'RADIANCE_ADD_BAND_5': -29.60731,
#                               'RADIANCE_ADD_BAND_6': -7.36307,
#                               'RADIANCE_ADD_BAND_7': -2.48175,
#                               'RADIANCE_ADD_BAND_8': -54.75499,
#                               'RADIANCE_ADD_BAND_9': -11.57121,
#                               'RADIANCE_MULT_BAND_1': 0.012161,
#                               'RADIANCE_MULT_BAND_10': 0.0003342,
#                               'RADIANCE_MULT_BAND_11': 0.0003342,
#                               'RADIANCE_MULT_BAND_2': 0.012453,
#                               'RADIANCE_MULT_BAND_3': 0.011475,
#                               'RADIANCE_MULT_BAND_4': 0.0096764,
#                               'RADIANCE_MULT_BAND_5': 0.0059215,
#                               'RADIANCE_MULT_BAND_6': 0.0014726,
#                               'RADIANCE_MULT_BAND_7': 0.00049635,
#                               'RADIANCE_MULT_BAND_8': 0.010951,
#                               'RADIANCE_MULT_BAND_9': 0.0023142,
#                               'REFLECTANCE_ADD_BAND_1': -0.1,
#                               'REFLECTANCE_ADD_BAND_2': -0.1,
#                               'REFLECTANCE_ADD_BAND_3': -0.1,
#                               'REFLECTANCE_ADD_BAND_4': -0.1,
#                               'REFLECTANCE_ADD_BAND_5': -0.1,
#                               'REFLECTANCE_ADD_BAND_6': -0.1,
#                               'REFLECTANCE_ADD_BAND_7': -0.1,
#                               'REFLECTANCE_ADD_BAND_8': -0.1,
#                               'REFLECTANCE_ADD_BAND_9': -0.1,
#                               'REFLECTANCE_MULT_BAND_1': 2e-05,
#                               'REFLECTANCE_MULT_BAND_2': 2e-05,
#                               'REFLECTANCE_MULT_BAND_3': 2e-05,
#                               'REFLECTANCE_MULT_BAND_4': 2e-05,
#                               'REFLECTANCE_MULT_BAND_5': 2e-05,
#                               'REFLECTANCE_MULT_BAND_6': 2e-05,
#                               'REFLECTANCE_MULT_BAND_7': 2e-05,
#                               'REFLECTANCE_MULT_BAND_8': 2e-05,
#                               'REFLECTANCE_MULT_BAND_9': 2e-05,
#                               'REFLECTIVE_LINES': 7371,
#                               'REFLECTIVE_SAMPLES': 7571,
#                               'REQUEST_ID': 'L2',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'ROLL_ANGLE': -0.001,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:48:00.4611360Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 122.90434771,
#                               'SUN_ELEVATION': 67.54383379,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7371,
#                               'THERMAL_SAMPLES': 7571,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'WRS_TYPE': 2,
#                               'system:asset_size': 1131511264,
#                               'system:footprint': {...},
#                               'system:index': 'LC08_044034_20130619',
#                               'system:time_end': 1371667680461,
#                               'system:time_start': 1371667680461},
#                'type': 'Image',
#                'version': 1742759744720687},
#               {'bands': [{...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...}],
#                'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20130705',
#                'properties': {'CLOUD_COVER': 38.85,
#                               'CLOUD_COVER_LAND': 12.17,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 2,
#                               'DATA_SOURCE_ELEVATION': 'GLS2000',
#                               'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#                               'DATE_ACQUIRED': '2013-07-05',
#                               'DATE_PRODUCT_GENERATED': 1599928730000,
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0167084,
#                               'ELLIPSOID': 'WGS84',
#                               'GEOMETRIC_RMSE_MODEL': 2.885,
#                               'GEOMETRIC_RMSE_MODEL_X': 1.79,
#                               'GEOMETRIC_RMSE_MODEL_Y': 2.262,
#                               'GEOMETRIC_RMSE_VERIFY': 2.002,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 1010,
#                               'GROUND_CONTROL_POINTS_VERIFY': 332,
#                               'GROUND_CONTROL_POINTS_VERSION': 5,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853,
#                               'K1_CONSTANT_BAND_11': 480.8883,
#                               'K2_CONSTANT_BAND_10': 1321.0789,
#                               'K2_CONSTANT_BAND_11': 1201.1442,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20130705_20200912_02_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342013186LGN01',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 15621,
#                               'PANCHROMATIC_SAMPLES': 15341,
#                               'PROCESSING_LEVEL': 'L1TP',
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#                               'RADIANCE_ADD_BAND_1': -60.73234,
#                               'RADIANCE_ADD_BAND_10': 0.1,
#                               'RADIANCE_ADD_BAND_11': 0.1,
#                               'RADIANCE_ADD_BAND_2': -62.19066,
#                               'RADIANCE_ADD_BAND_3': -57.30816,
#                               'RADIANCE_ADD_BAND_4': -48.32547,
#                               'RADIANCE_ADD_BAND_5': -29.57278,
#                               'RADIANCE_ADD_BAND_6': -7.35448,
#                               'RADIANCE_ADD_BAND_7': -2.47885,
#                               'RADIANCE_ADD_BAND_8': -54.69113,
#                               'RADIANCE_ADD_BAND_9': -11.55771,
#                               'RADIANCE_MULT_BAND_1': 0.012146,
#                               'RADIANCE_MULT_BAND_10': 0.0003342,
#                               'RADIANCE_MULT_BAND_11': 0.0003342,
#                               'RADIANCE_MULT_BAND_2': 0.012438,
#                               'RADIANCE_MULT_BAND_3': 0.011462,
#                               'RADIANCE_MULT_BAND_4': 0.0096651,
#                               'RADIANCE_MULT_BAND_5': 0.0059146,
#                               'RADIANCE_MULT_BAND_6': 0.0014709,
#                               'RADIANCE_MULT_BAND_7': 0.00049577,
#                               'RADIANCE_MULT_BAND_8': 0.010938,
#                               'RADIANCE_MULT_BAND_9': 0.0023115,
#                               'REFLECTANCE_ADD_BAND_1': -0.1,
#                               'REFLECTANCE_ADD_BAND_2': -0.1,
#                               'REFLECTANCE_ADD_BAND_3': -0.1,
#                               'REFLECTANCE_ADD_BAND_4': -0.1,
#                               'REFLECTANCE_ADD_BAND_5': -0.1,
#                               'REFLECTANCE_ADD_BAND_6': -0.1,
#                               'REFLECTANCE_ADD_BAND_7': -0.1,
#                               'REFLECTANCE_ADD_BAND_8': -0.1,
#                               'REFLECTANCE_ADD_BAND_9': -0.1,
#                               'REFLECTANCE_MULT_BAND_1': 2e-05,
#                               'REFLECTANCE_MULT_BAND_2': 2e-05,
#                               'REFLECTANCE_MULT_BAND_3': 2e-05,
#                               'REFLECTANCE_MULT_BAND_4': 2e-05,
#                               'REFLECTANCE_MULT_BAND_5': 2e-05,
#                               'REFLECTANCE_MULT_BAND_6': 2e-05,
#                               'REFLECTANCE_MULT_BAND_7': 2e-05,
#                               'REFLECTANCE_MULT_BAND_8': 2e-05,
#                               'REFLECTANCE_MULT_BAND_9': 2e-05,
#                               'REFLECTIVE_LINES': 7811,
#                               'REFLECTIVE_SAMPLES': 7671,
#                               'REQUEST_ID': 'L2',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'ROLL_ANGLE': -0.001,
#                               'SATURATION_BAND_1': 'N',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:48:03.9209730Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 122.93634469,
#                               'SUN_ELEVATION': 66.51599906,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7811,
#                               'THERMAL_SAMPLES': 7671,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'WRS_TYPE': 2,
#                               'system:asset_size': 1283497757,
#                               'system:footprint': {...},
#                               'system:index': 'LC08_044034_20130705',
#                               'system:time_end': 1373050083920,
#                               'system:time_start': 1373050083920},
#                'type': 'Image',
#                'version': 1742759744720687},
#               {'bands': [{...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...}],
#                'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20130721',
#                'properties': {'CLOUD_COVER': 37.4,
#                               'CLOUD_COVER_LAND': 6.11,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 2,
#                               'DATA_SOURCE_ELEVATION': 'GLS2000',
#                               'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#                               'DATE_ACQUIRED': '2013-07-21',
#                               'DATE_PRODUCT_GENERATED': 1599943048000,
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0159821,
#                               'ELLIPSOID': 'WGS84',
#                               'GEOMETRIC_RMSE_MODEL': 3.184,
#                               'GEOMETRIC_RMSE_MODEL_X': 2.12,
#                               'GEOMETRIC_RMSE_MODEL_Y': 2.375,
#                               'GEOMETRIC_RMSE_VERIFY': 1.364,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 1126,
#                               'GROUND_CONTROL_POINTS_VERIFY': 335,
#                               'GROUND_CONTROL_POINTS_VERSION': 5,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853,
#                               'K1_CONSTANT_BAND_11': 480.8883,
#                               'K2_CONSTANT_BAND_10': 1321.0789,
#                               'K2_CONSTANT_BAND_11': 1201.1442,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20130721_20200912_02_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342013202LGN01',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 15621,
#                               'PANCHROMATIC_SAMPLES': 15321,
#                               'PROCESSING_LEVEL': 'L1TP',
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#                               'RADIANCE_ADD_BAND_1': -60.81921,
#                               'RADIANCE_ADD_BAND_10': 0.1,
#                               'RADIANCE_ADD_BAND_11': 0.1,
#                               'RADIANCE_ADD_BAND_2': -62.27961,
#                               'RADIANCE_ADD_BAND_3': -57.39013,
#                               'RADIANCE_ADD_BAND_4': -48.39459,
#                               'RADIANCE_ADD_BAND_5': -29.61508,
#                               'RADIANCE_ADD_BAND_6': -7.365,
#                               'RADIANCE_ADD_BAND_7': -2.4824,
#                               'RADIANCE_ADD_BAND_8': -54.76936,
#                               'RADIANCE_ADD_BAND_9': -11.57424,
#                               'RADIANCE_MULT_BAND_1': 0.012164,
#                               'RADIANCE_MULT_BAND_10': 0.0003342,
#                               'RADIANCE_MULT_BAND_11': 0.0003342,
#                               'RADIANCE_MULT_BAND_2': 0.012456,
#                               'RADIANCE_MULT_BAND_3': 0.011478,
#                               'RADIANCE_MULT_BAND_4': 0.0096789,
#                               'RADIANCE_MULT_BAND_5': 0.005923,
#                               'RADIANCE_MULT_BAND_6': 0.001473,
#                               'RADIANCE_MULT_BAND_7': 0.00049648,
#                               'RADIANCE_MULT_BAND_8': 0.010954,
#                               'RADIANCE_MULT_BAND_9': 0.0023148,
#                               'REFLECTANCE_ADD_BAND_1': -0.1,
#                               'REFLECTANCE_ADD_BAND_2': -0.1,
#                               'REFLECTANCE_ADD_BAND_3': -0.1,
#                               'REFLECTANCE_ADD_BAND_4': -0.1,
#                               'REFLECTANCE_ADD_BAND_5': -0.1,
#                               'REFLECTANCE_ADD_BAND_6': -0.1,
#                               'REFLECTANCE_ADD_BAND_7': -0.1,
#                               'REFLECTANCE_ADD_BAND_8': -0.1,
#                               'REFLECTANCE_ADD_BAND_9': -0.1,
#                               'REFLECTANCE_MULT_BAND_1': 2e-05,
#                               'REFLECTANCE_MULT_BAND_2': 2e-05,
#                               'REFLECTANCE_MULT_BAND_3': 2e-05,
#                               'REFLECTANCE_MULT_BAND_4': 2e-05,
#                               'REFLECTANCE_MULT_BAND_5': 2e-05,
#                               'REFLECTANCE_MULT_BAND_6': 2e-05,
#                               'REFLECTANCE_MULT_BAND_7': 2e-05,
#                               'REFLECTANCE_MULT_BAND_8': 2e-05,
#                               'REFLECTANCE_MULT_BAND_9': 2e-05,
#                               'REFLECTIVE_LINES': 7811,
#                               'REFLECTIVE_SAMPLES': 7661,
#                               'REQUEST_ID': 'L2',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'ROLL_ANGLE': -0.001,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:48:01.8569090Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 126.27925661,
#                               'SUN_ELEVATION': 64.52790825,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7811,
#                               'THERMAL_SAMPLES': 7661,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'WRS_TYPE': 2,
#                               'system:asset_size': 1272838804,
#                               'system:footprint': {...},
#                               'system:index': 'LC08_044034_20130721',
#                               'system:time_end': 1374432481856,
#                               'system:time_start': 1374432481856},
#                'type': 'Image',
#                'version': 1742759744720687},
#               {'bands': [{...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...}],
#                'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20130806',
#                'properties': {'CLOUD_COVER': 40.18,
#                               'CLOUD_COVER_LAND': 19.38,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 2,
#                               'DATA_SOURCE_ELEVATION': 'GLS2000',
#                               'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#                               'DATE_ACQUIRED': '2013-08-06',
#                               'DATE_PRODUCT_GENERATED': 1599928061000,
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0142051,
#                               'ELLIPSOID': 'WGS84',
#                               'GEOMETRIC_RMSE_MODEL': 3.81,
#                               'GEOMETRIC_RMSE_MODEL_X': 2.417,
#                               'GEOMETRIC_RMSE_MODEL_Y': 2.945,
#                               'GEOMETRIC_RMSE_VERIFY': 1.5,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 955,
#                               'GROUND_CONTROL_POINTS_VERIFY': 277,
#                               'GROUND_CONTROL_POINTS_VERSION': 5,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853,
#                               'K1_CONSTANT_BAND_11': 480.8883,
#                               'K2_CONSTANT_BAND_10': 1321.0789,
#                               'K2_CONSTANT_BAND_11': 1201.1442,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20130806_20200912_02_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342013218LGN01',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 15601,
#                               'PANCHROMATIC_SAMPLES': 15341,
#                               'PROCESSING_LEVEL': 'L1TP',
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#                               'RADIANCE_ADD_BAND_1': -61.03252,
#                               'RADIANCE_ADD_BAND_10': 0.1,
#                               'RADIANCE_ADD_BAND_11': 0.1,
#                               'RADIANCE_ADD_BAND_2': -62.49804,
#                               'RADIANCE_ADD_BAND_3': -57.59141,
#                               'RADIANCE_ADD_BAND_4': -48.56432,
#                               'RADIANCE_ADD_BAND_5': -29.71894,
#                               'RADIANCE_ADD_BAND_6': -7.39083,
#                               'RADIANCE_ADD_BAND_7': -2.49111,
#                               'RADIANCE_ADD_BAND_8': -54.96145,
#                               'RADIANCE_ADD_BAND_9': -11.61484,
#                               'RADIANCE_MULT_BAND_1': 0.012207,
#                               'RADIANCE_MULT_BAND_10': 0.0003342,
#                               'RADIANCE_MULT_BAND_11': 0.0003342,
#                               'RADIANCE_MULT_BAND_2': 0.0125,
#                               'RADIANCE_MULT_BAND_3': 0.011518,
#                               'RADIANCE_MULT_BAND_4': 0.0097129,
#                               'RADIANCE_MULT_BAND_5': 0.0059438,
#                               'RADIANCE_MULT_BAND_6': 0.0014782,
#                               'RADIANCE_MULT_BAND_7': 0.00049822,
#                               'RADIANCE_MULT_BAND_8': 0.010992,
#                               'RADIANCE_MULT_BAND_9': 0.002323,
#                               'REFLECTANCE_ADD_BAND_1': -0.1,
#                               'REFLECTANCE_ADD_BAND_2': -0.1,
#                               'REFLECTANCE_ADD_BAND_3': -0.1,
#                               'REFLECTANCE_ADD_BAND_4': -0.1,
#                               'REFLECTANCE_ADD_BAND_5': -0.1,
#                               'REFLECTANCE_ADD_BAND_6': -0.1,
#                               'REFLECTANCE_ADD_BAND_7': -0.1,
#                               'REFLECTANCE_ADD_BAND_8': -0.1,
#                               'REFLECTANCE_ADD_BAND_9': -0.1,
#                               'REFLECTANCE_MULT_BAND_1': 2e-05,
#                               'REFLECTANCE_MULT_BAND_2': 2e-05,
#                               'REFLECTANCE_MULT_BAND_3': 2e-05,
#                               'REFLECTANCE_MULT_BAND_4': 2e-05,
#                               'REFLECTANCE_MULT_BAND_5': 2e-05,
#                               'REFLECTANCE_MULT_BAND_6': 2e-05,
#                               'REFLECTANCE_MULT_BAND_7': 2e-05,
#                               'REFLECTANCE_MULT_BAND_8': 2e-05,
#                               'REFLECTANCE_MULT_BAND_9': 2e-05,
#                               'REFLECTIVE_LINES': 7801,
#                               'REFLECTIVE_SAMPLES': 7671,
#                               'REQUEST_ID': 'L2',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'ROLL_ANGLE': -0.001,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:48:05.4109620Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 132.02278804,
#                               'SUN_ELEVATION': 61.70253096,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7801,
#                               'THERMAL_SAMPLES': 7671,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'WRS_TYPE': 2,
#                               'system:asset_size': 1337410616,
#                               'system:footprint': {...},
#                               'system:index': 'LC08_044034_20130806',
#                               'system:time_end': 1375814885410,
#                               'system:time_start': 1375814885410},
#                'type': 'Image',
#                'version': 1742759744720687},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20130822'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20130907'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20130923'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20131009'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20131025'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20131110'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20131126'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20131212'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20131228'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20140113'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20140129'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20140214'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20140318'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20140403'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20140419'},
#                'type': 'Image'},
#               {'bands': [{...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...}],
#                'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20140505',
#                'properties': {'CLOUD_COVER': 24.25,
#                               'CLOUD_COVER_LAND': 30.08,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 2,
#                               'DATA_SOURCE_ELEVATION': 'GLS2000',
#                               'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#                               'DATE_ACQUIRED': '2014-05-05',
#                               'DATE_PRODUCT_GENERATED': 1599830025000,
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0086472,
#                               'ELLIPSOID': 'WGS84',
#                               'GEOMETRIC_RMSE_MODEL': 5.983,
#                               'GEOMETRIC_RMSE_MODEL_X': 4.553,
#                               'GEOMETRIC_RMSE_MODEL_Y': 3.882,
#                               'GEOMETRIC_RMSE_VERIFY': 2.402,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 590,
#                               'GROUND_CONTROL_POINTS_VERIFY': 165,
#                               'GROUND_CONTROL_POINTS_VERSION': 5,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853,
#                               'K1_CONSTANT_BAND_11': 480.8883,
#                               'K2_CONSTANT_BAND_10': 1321.0789,
#                               'K2_CONSTANT_BAND_11': 1201.1442,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20140505_20200911_02_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342014125LGN01',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 15581,
#                               'PANCHROMATIC_SAMPLES': 15341,
#                               'PROCESSING_LEVEL': 'L1TP',
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#                               'RADIANCE_ADD_BAND_1': -61.70698,
#                               'RADIANCE_ADD_BAND_10': 0.1,
#                               'RADIANCE_ADD_BAND_11': 0.1,
#                               'RADIANCE_ADD_BAND_2': -63.1887,
#                               'RADIANCE_ADD_BAND_3': -58.22784,
#                               'RADIANCE_ADD_BAND_4': -49.101,
#                               'RADIANCE_ADD_BAND_5': -30.04736,
#                               'RADIANCE_ADD_BAND_6': -7.47251,
#                               'RADIANCE_ADD_BAND_7': -2.51863,
#                               'RADIANCE_ADD_BAND_8': -55.56882,
#                               'RADIANCE_ADD_BAND_9': -11.74319,
#                               'RADIANCE_MULT_BAND_1': 0.012341,
#                               'RADIANCE_MULT_BAND_10': 0.0003342,
#                               'RADIANCE_MULT_BAND_11': 0.0003342,
#                               'RADIANCE_MULT_BAND_2': 0.012638,
#                               'RADIANCE_MULT_BAND_3': 0.011646,
#                               'RADIANCE_MULT_BAND_4': 0.0098202,
#                               'RADIANCE_MULT_BAND_5': 0.0060095,
#                               'RADIANCE_MULT_BAND_6': 0.0014945,
#                               'RADIANCE_MULT_BAND_7': 0.00050373,
#                               'RADIANCE_MULT_BAND_8': 0.011114,
#                               'RADIANCE_MULT_BAND_9': 0.0023486,
#                               'REFLECTANCE_ADD_BAND_1': -0.1,
#                               'REFLECTANCE_ADD_BAND_2': -0.1,
#                               'REFLECTANCE_ADD_BAND_3': -0.1,
#                               'REFLECTANCE_ADD_BAND_4': -0.1,
#                               'REFLECTANCE_ADD_BAND_5': -0.1,
#                               'REFLECTANCE_ADD_BAND_6': -0.1,
#                               'REFLECTANCE_ADD_BAND_7': -0.1,
#                               'REFLECTANCE_ADD_BAND_8': -0.1,
#                               'REFLECTANCE_ADD_BAND_9': -0.1,
#                               'REFLECTANCE_MULT_BAND_1': 2e-05,
#                               'REFLECTANCE_MULT_BAND_2': 2e-05,
#                               'REFLECTANCE_MULT_BAND_3': 2e-05,
#                               'REFLECTANCE_MULT_BAND_4': 2e-05,
#                               'REFLECTANCE_MULT_BAND_5': 2e-05,
#                               'REFLECTANCE_MULT_BAND_6': 2e-05,
#                               'REFLECTANCE_MULT_BAND_7': 2e-05,
#                               'REFLECTANCE_MULT_BAND_8': 2e-05,
#                               'REFLECTANCE_MULT_BAND_9': 2e-05,
#                               'REFLECTIVE_LINES': 7791,
#                               'REFLECTIVE_SAMPLES': 7671,
#                               'REQUEST_ID': 'L2',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'ROLL_ANGLE': -0.001,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:45:42.7916370Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 134.89888726,
#                               'SUN_ELEVATION': 62.58410279,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7791,
#                               'THERMAL_SAMPLES': 7671,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'WRS_TYPE': 2,
#                               'system:asset_size': 1278139927,
#                               'system:footprint': {...},
#                               'system:index': 'LC08_044034_20140505',
#                               'system:time_end': 1399315542791,
#                               'system:time_start': 1399315542791},
#                'type': 'Image',
#                'version': 1742759744720687},
#               {'bands': [{...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
# ...
#                               'DATE_ACQUIRED': '2024-07-19',
#                               'DATE_PRODUCT_GENERATED': 1721721380000,
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0161423,
#                               'ELLIPSOID': 'WGS84',
#                               'GEOMETRIC_RMSE_MODEL': 5.493,
#                               'GEOMETRIC_RMSE_MODEL_X': 3.896,
#                               'GEOMETRIC_RMSE_MODEL_Y': 3.873,
#                               'GEOMETRIC_RMSE_VERIFY': 2.609,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 1032,
#                               'GROUND_CONTROL_POINTS_VERIFY': 449,
#                               'GROUND_CONTROL_POINTS_VERSION': 5,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853,
#                               'K1_CONSTANT_BAND_11': 480.8883,
#                               'K2_CONSTANT_BAND_10': 1321.0789,
#                               'K2_CONSTANT_BAND_11': 1201.1442,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20240719_20240723_02_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342024201LGN00',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 15621,
#                               'PANCHROMATIC_SAMPLES': 15341,
#                               'PROCESSING_LEVEL': 'L1TP',
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#                               'RADIANCE_ADD_BAND_1': -60.80003,
#                               'RADIANCE_ADD_BAND_10': 0.1,
#                               'RADIANCE_ADD_BAND_11': 0.1,
#                               'RADIANCE_ADD_BAND_2': -62.25998,
#                               'RADIANCE_ADD_BAND_3': -57.37204,
#                               'RADIANCE_ADD_BAND_4': -48.37933,
#                               'RADIANCE_ADD_BAND_5': -29.60574,
#                               'RADIANCE_ADD_BAND_6': -7.36268,
#                               'RADIANCE_ADD_BAND_7': -2.48162,
#                               'RADIANCE_ADD_BAND_8': -54.75209,
#                               'RADIANCE_ADD_BAND_9': -11.57059,
#                               'RADIANCE_MULT_BAND_1': 0.01216,
#                               'RADIANCE_MULT_BAND_10': 0.0003342,
#                               'RADIANCE_MULT_BAND_11': 0.0003342,
#                               'RADIANCE_MULT_BAND_2': 0.012452,
#                               'RADIANCE_MULT_BAND_3': 0.011474,
#                               'RADIANCE_MULT_BAND_4': 0.0096759,
#                               'RADIANCE_MULT_BAND_5': 0.0059211,
#                               'RADIANCE_MULT_BAND_6': 0.0014725,
#                               'RADIANCE_MULT_BAND_7': 0.00049632,
#                               'RADIANCE_MULT_BAND_8': 0.01095,
#                               'RADIANCE_MULT_BAND_9': 0.0023141,
#                               'REFLECTANCE_ADD_BAND_1': -0.1,
#                               'REFLECTANCE_ADD_BAND_2': -0.1,
#                               'REFLECTANCE_ADD_BAND_3': -0.1,
#                               'REFLECTANCE_ADD_BAND_4': -0.1,
#                               'REFLECTANCE_ADD_BAND_5': -0.1,
#                               'REFLECTANCE_ADD_BAND_6': -0.1,
#                               'REFLECTANCE_ADD_BAND_7': -0.1,
#                               'REFLECTANCE_ADD_BAND_8': -0.1,
#                               'REFLECTANCE_ADD_BAND_9': -0.1,
#                               'REFLECTANCE_MULT_BAND_1': 2e-05,
#                               'REFLECTANCE_MULT_BAND_2': 2e-05,
#                               'REFLECTANCE_MULT_BAND_3': 2e-05,
#                               'REFLECTANCE_MULT_BAND_4': 2e-05,
#                               'REFLECTANCE_MULT_BAND_5': 2e-05,
#                               'REFLECTANCE_MULT_BAND_6': 2e-05,
#                               'REFLECTANCE_MULT_BAND_7': 2e-05,
#                               'REFLECTANCE_MULT_BAND_8': 2e-05,
#                               'REFLECTANCE_MULT_BAND_9': 2e-05,
#                               'REFLECTIVE_LINES': 7811,
#                               'REFLECTIVE_SAMPLES': 7671,
#                               'REQUEST_ID': '1914616_00039',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'ROLL_ANGLE': -0.001,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:45:38.7922000Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 124.78910258,
#                               'SUN_ELEVATION': 64.35998172,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7811,
#                               'THERMAL_SAMPLES': 7671,
#                               'TIRS_SSM_MODEL': 'FINAL',
#                               'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'WRS_TYPE': 2,
#                               'system:asset_size': 1225081996,
#                               'system:footprint': {...},
#                               'system:index': 'LC08_044034_20240719',
#                               'system:time_end': 1721414738792,
#                               'system:time_start': 1721414738792},
#                'type': 'Image',
#                'version': 1742759744720687},
#               {'bands': [{...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...},
#                          {...}],
#                'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20240804',
#                'properties': {'CLOUD_COVER': 37.62,
#                               'CLOUD_COVER_LAND': 7,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 2,
#                               'DATA_SOURCE_ELEVATION': 'GLS2000',
#                               'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#                               'DATE_ACQUIRED': '2024-08-04',
#                               'DATE_PRODUCT_GENERATED': 1723099515000,
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0145005,
#                               'ELLIPSOID': 'WGS84',
#                               'GEOMETRIC_RMSE_MODEL': 5.26,
#                               'GEOMETRIC_RMSE_MODEL_X': 3.668,
#                               'GEOMETRIC_RMSE_MODEL_Y': 3.77,
#                               'GEOMETRIC_RMSE_VERIFY': 2.397,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 970,
#                               'GROUND_CONTROL_POINTS_VERIFY': 410,
#                               'GROUND_CONTROL_POINTS_VERSION': 5,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853,
#                               'K1_CONSTANT_BAND_11': 480.8883,
#                               'K2_CONSTANT_BAND_10': 1321.0789,
#                               'K2_CONSTANT_BAND_11': 1201.1442,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20240804_20240808_02_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342024217LGN00',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 15601,
#                               'PANCHROMATIC_SAMPLES': 15341,
#                               'PROCESSING_LEVEL': 'L1TP',
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#                               'RADIANCE_ADD_BAND_1': -60.99698,
#                               'RADIANCE_ADD_BAND_10': 0.1,
#                               'RADIANCE_ADD_BAND_11': 0.1,
#                               'RADIANCE_ADD_BAND_2': -62.46165,
#                               'RADIANCE_ADD_BAND_3': -57.55787,
#                               'RADIANCE_ADD_BAND_4': -48.53604,
#                               'RADIANCE_ADD_BAND_5': -29.70164,
#                               'RADIANCE_ADD_BAND_6': -7.38653,
#                               'RADIANCE_ADD_BAND_7': -2.48966,
#                               'RADIANCE_ADD_BAND_8': -54.92944,
#                               'RADIANCE_ADD_BAND_9': -11.60807,
#                               'RADIANCE_MULT_BAND_1': 0.012199,
#                               'RADIANCE_MULT_BAND_10': 0.0003342,
#                               'RADIANCE_MULT_BAND_11': 0.0003342,
#                               'RADIANCE_MULT_BAND_2': 0.012492,
#                               'RADIANCE_MULT_BAND_3': 0.011512,
#                               'RADIANCE_MULT_BAND_4': 0.0097072,
#                               'RADIANCE_MULT_BAND_5': 0.0059403,
#                               'RADIANCE_MULT_BAND_6': 0.0014773,
#                               'RADIANCE_MULT_BAND_7': 0.00049793,
#                               'RADIANCE_MULT_BAND_8': 0.010986,
#                               'RADIANCE_MULT_BAND_9': 0.0023216,
#                               'REFLECTANCE_ADD_BAND_1': -0.1,
#                               'REFLECTANCE_ADD_BAND_2': -0.1,
#                               'REFLECTANCE_ADD_BAND_3': -0.1,
#                               'REFLECTANCE_ADD_BAND_4': -0.1,
#                               'REFLECTANCE_ADD_BAND_5': -0.1,
#                               'REFLECTANCE_ADD_BAND_6': -0.1,
#                               'REFLECTANCE_ADD_BAND_7': -0.1,
#                               'REFLECTANCE_ADD_BAND_8': -0.1,
#                               'REFLECTANCE_ADD_BAND_9': -0.1,
#                               'REFLECTANCE_MULT_BAND_1': 2e-05,
#                               'REFLECTANCE_MULT_BAND_2': 2e-05,
#                               'REFLECTANCE_MULT_BAND_3': 2e-05,
#                               'REFLECTANCE_MULT_BAND_4': 2e-05,
#                               'REFLECTANCE_MULT_BAND_5': 2e-05,
#                               'REFLECTANCE_MULT_BAND_6': 2e-05,
#                               'REFLECTANCE_MULT_BAND_7': 2e-05,
#                               'REFLECTANCE_MULT_BAND_8': 2e-05,
#                               'REFLECTANCE_MULT_BAND_9': 2e-05,
#                               'REFLECTIVE_LINES': 7801,
#                               'REFLECTIVE_SAMPLES': 7671,
#                               'REQUEST_ID': '1920849_00039',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'ROLL_ANGLE': -0.001,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:45:39.2904429Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 130.38995586,
#                               'SUN_ELEVATION': 61.6714158,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7801,
#                               'THERMAL_SAMPLES': 7671,
#                               'TIRS_SSM_MODEL': 'FINAL',
#                               'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'WRS_TYPE': 2,
#                               'system:asset_size': 1276469794,
#                               'system:footprint': {...},
#                               'system:index': 'LC08_044034_20240804',
#                               'system:time_end': 1722797139290,
#                               'system:time_start': 1722797139290},
#                'type': 'Image',
#                'version': 1742759744720687},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20240820'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20240905'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20240921'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20241007'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20241023'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20241108'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20241124'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20241210'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20241226'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20250111'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20250127'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20250212'},
#                'type': 'Image'},
#               {'bands': [{...}],
#                'properties': {'system:index': 'LC08_044034_20250228'},
#                'type': 'Image'}],
#  'id': 'LANDSAT/LC08/C02/T1_TOA',
#  'type': 'ImageCollection',
#  'version': 1742759744720687}

# %% [markdown]
# Inspect the list of images in the output ImageCollection and note that the when the condition evaluated by the `If()` algorithm is true, the output contains an image, if it is not true, it contains an empty image. Although this demonstrates a server-side conditional function, avoid `If()` in general and use filters instead.

# %% [markdown]
# ## Reducing an ImageCollection

# %% [markdown]
# To composite images in an ImageCollection, use `imageCollection.reduce()`. This will composite all the images in the collection to a single image representing, for example, the min, max, mean or standard deviation of the images. For example, to create a median value image from a collection:

# %%
# Load a Landsat 8 collection for a specific date range.
collection2 = collection.filterDate('2014-01-01', '2015-01-01')

# Compute a median image and display.
median = collection2.median();

# Use folium to visualize the imagery.
map2 = folium.Map(location=[37.7726,-122.3578],zoom_start=12)
map2.addLayer(median, {'bands': ['B4', 'B3', 'B2'], 'max': 0.3}, 'median')
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5714d251455fbd00e4831b2a63ef34f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5714d251455fbd00e4831b2a63ef34f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5714d251455fbd00e4831b2a63ef34f4 = L.map(
#                 &quot;map_5714d251455fbd00e4831b2a63ef34f4&quot;,
#                 {
#                     center: [37.7726, -122.3578],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d3e643ec08ab2f832df4a4fa77afe47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d3e643ec08ab2f832df4a4fa77afe47.addTo(map_5714d251455fbd00e4831b2a63ef34f4);
#
#
#             var tile_layer_baf5984172759b9ebf08cd2e36767bbb = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/522364178051/maps/bc0403c10ed89768fd04b609072f4d8a-eea2e1ef4235433a062176df2b80113a/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_baf5984172759b9ebf08cd2e36767bbb.addTo(map_5714d251455fbd00e4831b2a63ef34f4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# At each location in the output image, in each band, the pixel value is the median of all unmasked pixels in the input imagery (the images in the collection). In the previous example, `median()` is a convenience method for the following call:

# %%
# Reduce the collection with a median reducer.
median_bis = collection2.reduce(ee.Reducer.median())

# Display the median image.
map2.addLayer(median_bis, {'bands': ['B4_median', 'B3_median', 'B2_median'], 'max': 0.3}, 'median_bis')
folium.LayerControl().add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5714d251455fbd00e4831b2a63ef34f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5714d251455fbd00e4831b2a63ef34f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5714d251455fbd00e4831b2a63ef34f4 = L.map(
#                 &quot;map_5714d251455fbd00e4831b2a63ef34f4&quot;,
#                 {
#                     center: [37.7726, -122.3578],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d3e643ec08ab2f832df4a4fa77afe47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d3e643ec08ab2f832df4a4fa77afe47.addTo(map_5714d251455fbd00e4831b2a63ef34f4);
#
#
#             var tile_layer_baf5984172759b9ebf08cd2e36767bbb = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/522364178051/maps/bc0403c10ed89768fd04b609072f4d8a-eea2e1ef4235433a062176df2b80113a/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_baf5984172759b9ebf08cd2e36767bbb.addTo(map_5714d251455fbd00e4831b2a63ef34f4);
#
#
#             tile_layer_8d3e643ec08ab2f832df4a4fa77afe47.addTo(map_5714d251455fbd00e4831b2a63ef34f4);
#
#
#             tile_layer_baf5984172759b9ebf08cd2e36767bbb.addTo(map_5714d251455fbd00e4831b2a63ef34f4);
#
#
#             var tile_layer_797ae1f63f29c93029ad0f2ef531a2e3 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/522364178051/maps/bb850e6f47175abe7bfae15200f8e25a-4f788d33bd4a2153be8fb0a82f3eae84/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_797ae1f63f29c93029ad0f2ef531a2e3.addTo(map_5714d251455fbd00e4831b2a63ef34f4);
#
#
#             var layer_control_c46792dede0f05024a31c796b0057c3f_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_8d3e643ec08ab2f832df4a4fa77afe47,
#                 },
#                 overlays :  {
#                     &quot;median&quot; : tile_layer_baf5984172759b9ebf08cd2e36767bbb,
#                     &quot;median_bis&quot; : tile_layer_797ae1f63f29c93029ad0f2ef531a2e3,
#                 },
#             };
#             let layer_control_c46792dede0f05024a31c796b0057c3f = L.control.layers(
#                 layer_control_c46792dede0f05024a31c796b0057c3f_layers.base_layers,
#                 layer_control_c46792dede0f05024a31c796b0057c3f_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_5714d251455fbd00e4831b2a63ef34f4);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Note that the band names differ as a result of using reduce() instead of the convenience method. Specifically, the names of the reducer have been appended to the band names.

# %% [markdown]
# ## Iterating over an ImageCollection

# %% [markdown]
# Although `map()` applies a function to every image in a collection, the function visits every image in the collection independently.
#
# Suppose you want to compute a cumulative anomaly ($A_t$) at time t from a time series. To obtain a recursively defined series of the form $A_t = f(Image_t, A_{t-1})$, mapping won't work because the function ($f$) depends on the previous result ($A_{t-1}$).
#
# For example, suppose you want to compute a series of cumulative Normalized Difference Vegetation Index (NDVI) anomaly images relative to a baseline. Let $A_0 = 0$ and $f(Image_t, A_{t-1}) = Image_t + A_{t-1}$ where $A_{t-1}$ is the cumulative anomaly up to time t-1 and $Image_t$ is the anomaly at time t. Use `imageCollection.iterate()` to make this recursively defined ImageCollection.
#
# In the following example, the function `accumulate()` takes two parameters: an image in the collection, and a list of all the previous outputs. With each call to `iterate()`, the anomaly is added to the running sum and the result is added to the list. The final result is passed to the ImageCollection constructor to get a new sequence of images:

# %%
# Load MODIS EVI (Enhanced Vegetation index) imagery.
collection = ee.ImageCollection('MODIS/006/MYD13A1').select('EVI')

# Define reference conditions from the first 10 years of data
# Sort chronologically in descending order
reference = collection.filterDate('2001-01-01', '2010-12-31').sort('system:time_start', False)

# Compute the mean of the first 10 years.
mean = reference.mean()

# Compute anomalies by subtracting the 2001-2010 mean from each image in a
# collection of 2011-2014 images. Copy the date metadata over to the
# computed anomaly images in the new collection.

def subtracting(image):
  return image.subtract(mean).set('system:time_start', image.get('system:time_start'))

filtered = collection.filterDate('2011-01-01', '2014-12-31')

series = collection.map(subtracting)
series_sum = series.sum()

# Display cumulative anomalies.
# Use folium to visualize the imagery.
map3 = folium.Map(location=[40.2,-100.811],zoom_start=5)
map3.addLayer(series_sum, {'min': -60000, 'max': 60000, 'palette': ['FF0000', '000000', '00FF00']}, 'EVI anomaly')
map3
# Out:
# /exports/csce/datastore/geos/users/s2112771/miniforge3/envs/sensebook/lib/python3.12/site-packages/ee/deprecation.py:207: DeprecationWarning:
#
# Attention required for MODIS/006/MYD13A1! You are using a deprecated asset.
# To make sure your code keeps working, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/MODIS_006_MYD13A1
#
#   warnings.warn(warning, category=DeprecationWarning)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_316638f12efd916073510dfd7b44a9da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_316638f12efd916073510dfd7b44a9da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_316638f12efd916073510dfd7b44a9da = L.map(
#                 &quot;map_316638f12efd916073510dfd7b44a9da&quot;,
#                 {
#                     center: [40.2, -100.811],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_475e4d557c8661dc38d7e7614c1a8271 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_475e4d557c8661dc38d7e7614c1a8271.addTo(map_316638f12efd916073510dfd7b44a9da);
#
#
#             var tile_layer_0833f7893a434a541feb4dad0a436142 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/522364178051/maps/c8e214a7a8045c234fe4a72b2ca308cb-90b3e544df8a6a017cff193cda738485/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0833f7893a434a541feb4dad0a436142.addTo(map_316638f12efd916073510dfd7b44a9da);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Plotting time series

# %%
# %matplotlib inline
from IPython.display import Image
import ee, datetime
import pandas as pd
from pylab import *
from matplotlib.pylab import rcParams


# Define point in the Amazon rainforest
point = ee.Geometry.Point(-65.544, -4.894)

# Get info from the point

info = collection.getRegion(point,500).getInfo() # change colelction by series
print(info)

# Reshape image collection 
# Spearate header from data, and store data in an array
header = info[0]
data = array(info[1:])

# Extract time from data
iTime = header.index('time')
time = [datetime.datetime.fromtimestamp(i/1000) for i in (data[0:,iTime].astype(int))]

# List of used image bands
band_list = ['EVI']

iBands = [header.index(b) for b in band_list]
yData = data[0:,iBands].astype(np.float64)
#print(yData)

evi = yData[:,0]*0.0001 # USGS specifications: scale factor
#print(evi)

# Reshape EVI array into Pandas Dataframe
df = pd.DataFrame(data=evi, columns=['EVI'])
#print(df)

df['Date'] = pd.Series(time, index=df.index)
#print(df)
# Out:
# [['id', 'longitude', 'latitude', 'time', 'EVI'], ['2002_07_04', -65.54332891757059, -4.893572510241094, 1025740800000, 6161], ['2002_07_20', -65.54332891757059, -4.893572510241094, 1027123200000, 1731], ['2002_08_05', -65.54332891757059, -4.893572510241094, 1028505600000, 5028], ['2002_08_21', -65.54332891757059, -4.893572510241094, 1029888000000, 5625], ['2002_09_06', -65.54332891757059, -4.893572510241094, 1031270400000, 5806], ['2002_09_22', -65.54332891757059, -4.893572510241094, 1032652800000, 7038], ['2002_10_08', -65.54332891757059, -4.893572510241094, 1034035200000, 3037], ['2002_10_24', -65.54332891757059, -4.893572510241094, 1035417600000, 6345], ['2002_11_09', -65.54332891757059, -4.893572510241094, 1036800000000, 6451], ['2002_11_25', -65.54332891757059, -4.893572510241094, 1038182400000, 3734], ['2002_12_11', -65.54332891757059, -4.893572510241094, 1039564800000, 3676], ['2002_12_27', -65.54332891757059, -4.893572510241094, 1040947200000, 2414], ['2003_01_09', -65.54332891757059, -4.893572510241094, 1042070400000, 1303], ['2003_01_25', -65.54332891757059, -4.893572510241094, 1043452800000, 4368], ['2003_02_10', -65.54332891757059, -4.893572510241094, 1044835200000, 2398], ['2003_02_26', -65.54332891757059, -4.893572510241094, 1046217600000, 5063], ['2003_03_14', -65.54332891757059, -4.893572510241094, 1047600000000, 6489], ['2003_03_30', -65.54332891757059, -4.893572510241094, 1048982400000, 3018], ['2003_04_15', -65.54332891757059, -4.893572510241094, 1050364800000, 4505], ['2003_05_01', -65.54332891757059, -4.893572510241094, 1051747200000, 5975], ['2003_05_17', -65.54332891757059, -4.893572510241094, 1053129600000, 5449], ['2003_06_02', -65.54332891757059, -4.893572510241094, 1054512000000, 4415], ['2003_06_18', -65.54332891757059, -4.893572510241094, 1055894400000, 4225], ['2003_07_04', -65.54332891757059, -4.893572510241094, 1057276800000, 4803], ['2003_07_20', -65.54332891757059, -4.893572510241094, 1058659200000, 5389], ['2003_08_05', -65.54332891757059, -4.893572510241094, 1060041600000, 4999], ['2003_08_21', -65.54332891757059, -4.893572510241094, 1061424000000, 5297], ['2003_09_06', -65.54332891757059, -4.893572510241094, 1062806400000, 5297], ['2003_09_22', -65.54332891757059, -4.893572510241094, 1064188800000, 6019], ['2003_10_08', -65.54332891757059, -4.893572510241094, 1065571200000, 5019], ['2003_10_24', -65.54332891757059, -4.893572510241094, 1066953600000, 2918], ['2003_11_09', -65.54332891757059, -4.893572510241094, 1068336000000, 3391], ['2003_11_25', -65.54332891757059, -4.893572510241094, 1069718400000, 5652], ['2003_12_11', -65.54332891757059, -4.893572510241094, 1071100800000, 5808], ['2003_12_27', -65.54332891757059, -4.893572510241094, 1072483200000, 4594], ['2004_01_09', -65.54332891757059, -4.893572510241094, 1073606400000, 4846], ['2004_01_25', -65.54332891757059, -4.893572510241094, 1074988800000, 2300], ['2004_02_10', -65.54332891757059, -4.893572510241094, 1076371200000, 3367], ['2004_02_26', -65.54332891757059, -4.893572510241094, 1077753600000, 3979], ['2004_03_13', -65.54332891757059, -4.893572510241094, 1079136000000, 5300], ['2004_03_29', -65.54332891757059, -4.893572510241094, 1080518400000, 5107], ['2004_04_14', -65.54332891757059, -4.893572510241094, 1081900800000, 4095], ['2004_04_30', -65.54332891757059, -4.893572510241094, 1083283200000, 1118], ['2004_05_16', -65.54332891757059, -4.893572510241094, 1084665600000, 5535], ['2004_06_01', -65.54332891757059, -4.893572510241094, 1086048000000, 4823], ['2004_06_17', -65.54332891757059, -4.893572510241094, 1087430400000, 5608], ['2004_07_03', -65.54332891757059, -4.893572510241094, 1088812800000, 5021], ['2004_07_19', -65.54332891757059, -4.893572510241094, 1090195200000, 4772], ['2004_08_04', -65.54332891757059, -4.893572510241094, 1091577600000, 5371], ['2004_08_20', -65.54332891757059, -4.893572510241094, 1092960000000, 5867], ['2004_09_05', -65.54332891757059, -4.893572510241094, 1094342400000, 5136], ['2004_09_21', -65.54332 ...

# %%
# Plotting

rcParams['figure.figsize'] = 15, 6
df.plot(y='EVI',x='Date')
plt.show()
